# %% [markdown]
# <a href="https://colab.research.google.com/github/Nippun22/PythonLibraries/blob/main/codeBasics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#making dataframe using dictionary
import pandas as pd
weather_data={
    'days':['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017','1/7/2017'],
    'temperature': [35,32,36,28,24,32,31],
    'windspeed':[6,7,2,7,4,2,1],
    'event':['Rain','Snow','Sunny','Rain','Sunny','Snow','Rain']
}
df=pd.DataFrame(weather_data)
df
# Out:
#        days  temperature  windspeed  event
# 0  1/1/2017           35          6   Rain
# 1  1/2/2017           32          7   Snow
# 2  1/3/2017           36          2  Sunny
# 3  1/4/2017           28          7   Rain
# 4  1/5/2017           24          4  Sunny
# 5  1/6/2017           32          2   Snow
# 6  1/7/2017           31          1   Rain

# %%
row, columns= df.shape
row
columns
# Out:
# 4

# %%
df.head(2)
df.tail(1)
# Out:
#        days  temperature  windspeed event
# 6  1/7/2017           31          1  Rain

# %%
df[2:5]
# Out:
#        days  temperature  windspeed  event
# 2  1/3/2017           36          2  Sunny
# 3  1/4/2017           28          7   Rain
# 4  1/5/2017           24          4  Sunny

# %%
df.columns
# Out:
# Index(['days', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df.days
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# 6    1/7/2017
# Name: days, dtype: object

# %%
df.event
# Out:
# 0     Rain
# 1     Snow
# 2    Sunny
# 3     Rain
# 4    Sunny
# 5     Snow
# 6     Rain
# Name: event, dtype: object

# %%
df['days']
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# 6    1/7/2017
# Name: days, dtype: object

# %%
df[['event','days']]
# Out:
#    event      days
# 0   Rain  1/1/2017
# 1   Snow  1/2/2017
# 2  Sunny  1/3/2017
# 3   Rain  1/4/2017
# 4  Sunny  1/5/2017
# 5   Snow  1/6/2017
# 6   Rain  1/7/2017

# %%
df['temperature'].min()
# Out:
# 24

# %%
df.describe()
# Out:
#        temperature  windspeed
# count     7.000000   7.000000
# mean     31.142857   4.142857
# std       4.099942   2.544836
# min      24.000000   1.000000
# 25%      29.500000   2.000000
# 50%      32.000000   4.000000
# 75%      33.500000   6.500000
# max      36.000000   7.000000

# %%
type(df['event'])
# Out:
# pandas.core.series.Series

# %%
df[df.temperature>=32]
# Out:
#        days  temperature  windspeed  event
# 0  1/1/2017           35          6   Rain
# 1  1/2/2017           32          7   Snow
# 2  1/3/2017           36          2  Sunny
# 5  1/6/2017           32          2   Snow

# %%
df[df.temperature==df['temperature'].max()]
# Out:
#        days  temperature  windspeed  event
# 2  1/3/2017           36          2  Sunny

# %%
df[['days','temperature']][df.temperature==df.temperature.max()]
# Out:
#        days  temperature
# 2  1/3/2017           36

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df.set_index('days',inplace=True)

# %%
df.loc['1/3/2017']
# Out:
# temperature       36
# windspeed          2
# event          Sunny
# Name: 1/3/2017, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df.set_index('event',inplace=True)

# %%
df
# Out:
#        index      days  temperature  windspeed
# event
# Rain       0  1/1/2017           35          6
# Snow       1  1/2/2017           32          7
# Sunny      2  1/3/2017           36          2
# Rain       3  1/4/2017           28          7
# Sunny      4  1/5/2017           24          4
# Snow       5  1/6/2017           32          2
# Rain       6  1/7/2017           31          1

# %%
df.loc['Snow']
# Out:
#        index      days  temperature  windspeed
# event
# Snow       1  1/2/2017           32          7
# Snow       5  1/6/2017           32          2

# %%
type(df['event'])
# Out:
# pandas.core.series.Series

# %%
df[['event','days']]
# Out:
#    event      days
# 0   Rain  1/1/2017
# 1   Snow  1/2/2017
# 2  Sunny  1/3/2017
# 3   Rain  1/4/2017
# 4  Sunny  1/5/2017
# 5   Snow  1/6/2017
# 6   Rain  1/7/2017

# %%
import pandas as pd
weather_data={
    'day':['1/1/2017','1/2/2017','1/3/2017'],
    'temperaute':[32,35,28],
    'windspeed':[6,7,2],
    'event':['Rain','Sunny','Snow']
}
df1=pd.DataFrame(weather_data)
df1
# Out:
#         day  temperaute  windspeed  event
# 0  1/1/2017          32          6   Rain
# 1  1/2/2017          35          7  Sunny
# 2  1/3/2017          28          2   Snow

# %%
weather=[
    ('1/1/2017',32,6,'Rain'),
    ('1/2/2017',35,7,'Sunny'),
    ('1/3/2017',28,2,'Snow')
] #it's a list of tuple
df2=pd.DataFrame(weather,columns=['day','temperature','windspeed','event'])
df2
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
weather_data=[
    {'day':'1/1/2017', 'temperature': 32,'windspeed':6,'event':'Rain'},
    {'day':'1/2/2017', 'temperature': 35,'windspeed':7,'event':'Sunny'},
    {'day':'1/3/2017', 'temperature': 28,'windspeed':2,'event':'Snow'}
]
df3=pd.DataFrame(weather_data)
df3
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
""" different types of ways to create a DataFrame
1. Using CSV -> pd.read_csv  (.csv)
2. Using Excel -> pd.read_excel  (.xls)
3. From python dictionary -> pd.DataFrame(dict1)
4. From list of tuples -> pd.DataFrame(list1,columns='a', 'b')
5. From list of dictionaries -> pd.DataFrame(dict1)
"""

# %%
df=pd.read_csv("/content/people_data.csv")
df
# Out:
#   First Name Last Name     Sex                       Email Date of birth  \
# 0     Shelby   Terrell    Male        elijah57@example.net    1945-10-26
# 1    Phillip   Summers  Female       bethany14@example.com    1910-03-24
# 2   Kristine    Travis    Male       bthompson@example.com    1992-07-02
# 3    Yesenia  Martinez    Male   kaitlinkaiser@example.com    2017-08-03
# 4       Lori      Todd    Male  buchananmanuel@example.net    1938-12-01
#
#             Job Title
# 0     Games developer
# 1      Phytotherapist
# 2           Homeopath
# 3   Market researcher
# 4  Veterinary surgeon

# %%
#to skip first row: df=pd.read_csv("----",skiprows=1) or df=pd.read_csv("----",header=1)
# when u don't have header -> header=None
#when header not there and u want to mention column names-> df=pd.read_csv("----",header= None, names=['a','b','c'])

# %%
df=pd.read_csv("/content/people_data.csv",nrows=3)
df
# Out:
#   First Name Last Name     Sex                  Email Date of birth  \
# 0     Shelby   Terrell    Male   elijah57@example.net    1945-10-26
# 1    Phillip   Summers  Female  bethany14@example.com    1910-03-24
# 2   Kristine    Travis    Male  bthompson@example.com    1992-07-02
#
#          Job Title
# 0  Games developer
# 1   Phytotherapist
# 2        Homeopath

# %%
 df.to_csv('new.csv',index=False)

# %%
df.columns
# Out:
# Index(['First Name', 'Last Name', 'Sex', 'Email', 'Date of birth',
#        'Job Title'],
#       dtype='object')

# %%
df.to_csv("new.csv",columns=['First Name','Job Title'])

# %%
#read excel file
df=pd.read_excel("/content/people_data.xlsx")
df
# Out:
#   First Name Last Name     Sex                       Email Date of birth  \
# 0     Shelby   Terrell    Male        elijah57@example.net    1945-10-26
# 1    Phillip   Summers  Female       bethany14@example.com    1910-03-24
# 2   Kristine    Travis    Male       bthompson@example.com    1992-07-02
# 3    Yesenia  Martinez    Male   kaitlinkaiser@example.com    2017-08-03
# 4       Lori      Todd    Male  buchananmanuel@example.net    1938-12-01
#
#             Job Title
# 0     Games developer
# 1      Phytotherapist
# 2           Homeopath
# 3   Market researcher
# 4  Veterinary surgeon
